# %%
import pandas as pd
import numpy as np
# import matplot lib
##%matplotlib inline
##import matplotlib.pyplot as plt
import streamlit as st

# %%
##st.text('Fixed width text')
##st.markdown('_Markdown_') # see #*
##st.caption('Balloons. Hundreds of them...')
##st.latex(r''' e^{i\pi} + 1 = 0 ''')
##st.write('Most objects') # df, err, func, keras!
##st.write(['st', 'is <', 3]) # see *
##st.title('My title')
##st.header('My header')
##st.subheader('My sub')
##st.code('for i in range(8): foo()')

# %%
# Import Data
health_data = pd.read_csv("C:/Users/McLovin/.spyder-py3/New Data/oura_2019-01-01_2023-09-09_trends_Original.csv")

# %%
health_data
# Out:
#            date  Sleep Score  ...  HRV Balance Score  Recovery Index Score
# 0    2021-01-13         83.0  ...                NaN                  99.0
# 1    2021-01-14         76.0  ...                NaN                  69.0
# 2    2021-01-15         78.0  ...                NaN                  96.0
# 3    2021-01-16         69.0  ...                NaN                  51.0
# 4    2021-01-17         78.0  ...                NaN                  50.0
# ..          ...          ...  ...                ...                   ...
# 965  2023-07-22          NaN  ...                NaN                   NaN
# 966  2023-07-29          NaN  ...                NaN                   NaN
# 967  2023-07-31          NaN  ...                NaN                   NaN
# 968  2023-08-07          NaN  ...                NaN                   NaN
# 969  2023-09-05          NaN  ...                NaN                   NaN
#
# [970 rows x 54 columns]

# %%
# !jupyter nbconvert --to script test.ipynb
with open('test.py', 'r') as f:
    lines = f.readlines()
with open('test.py', 'w') as f:
    for line in lines:
        if 'nbconvert --to script' in line:
            break
        else:
            f.write(line)
# Out:
# [NbConvertApp] Converting notebook test.ipynb to script
# [NbConvertApp] Writing 1026 bytes to test.py
